# %% [markdown]
# ## Matplotlib con Seaborn
# Es una biblioteca para graficar, se utilisa mucho en relación con pandas. \
# Graficas posibles: https://seaborn.pydata.org/examples/index.html \
# Colores: https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Vamos a usar tres datasets que son parte de el paquete seaborn.

# %%
tip = sns.load_dataset('tips')
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip['percent']=tip['tip']/tip['total_bill']
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
tip.describe()
# Out:
#        total_bill         tip        size     percent
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672    0.160803
# std      8.902412    1.383638    0.951100    0.061072
# min      3.070000    1.000000    1.000000    0.035638
# 25%     13.347500    2.000000    2.000000    0.129127
# 50%     17.795000    2.900000    2.000000    0.154770
# 75%     24.127500    3.562500    3.000000    0.191475
# max     50.810000   10.000000    6.000000    0.710345

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Guia de colores
# ![Image](https://python-graph-gallery.com/wp-content/uploads/100_Color_names_python-768x480.png)

# %% [markdown]
# ### Graficas de distribución
# https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
sns.distplot(titanic['age'].dropna())

# %%
sns.distplot(titanic['age'].dropna(), bins=40, 
             hist=True, color="g",kde=True, 
             rug=True, vertical=True)

# %%
sns.distplot(titanic['age'].dropna(), rug=True, 
             bins=15, vertical=True, rug_kws={"color": "k"},
             kde_kws={"color": "k", "lw": 3, "label": "KDE", 
                      "alpha":1, "lw":2},
             hist_kws={"histtype": "barstacked", "linewidth": 5, 
                       "alpha": .5, "color": "crimson", 
                       "label":"Hist"})

# %%
bins = np.linspace(0, 90, 13)
sns.set(style="darkgrid")
sns.distplot(titanic['age'].dropna(), rug=False, 
             bins=bins, vertical=True, 
             kde_kws={"color": "k", "lw": 3, "label": "KDE", 
                      "alpha":.5, "lw":2},
             hist_kws={"histtype": "bar", "linewidth": 5, 
                       "alpha": .5, "color": "crimson", 
                       "label":"Hist"})

# %%
f = plt.figure(figsize=(6, 6))
gs = f.add_gridspec(2, 2)

with sns.axes_style("darkgrid"):
    ax = f.add_subplot(gs[0, 0])
    sns.distplot(titanic['age'].dropna(), bins=10, 
                 hist=True, color="red",kde=True, 
                 rug=True, vertical=False, ax=ax)

with sns.axes_style("white"):
    ax = f.add_subplot(gs[0, 1])
    sns.distplot(titanic['age'].dropna(), bins=10, 
                 hist=True, color="red",kde=True, 
                 rug=True, vertical=False, ax=ax)

with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[1, 0])
    sns.distplot(titanic['age'].dropna(), bins=10, 
                 hist=True, color="red",kde=True, 
                 rug=True, vertical=False, ax=ax)

with sns.axes_style("whitegrid"):
    ax = f.add_subplot(gs[1, 1])
    sns.distplot(titanic['age'].dropna(), bins=10, 
                 hist=True, color="red",kde=True, 
                 rug=True, vertical=False, ax=ax)

f.tight_layout()

# %% [markdown]
# ### Graficas de pie
# Probablemente el peor tipo, si la haces 3d empeora. Siempre que se pueda usar graficas de barras en lugar.

# %%
val=tip['day'].value_counts()
val
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
val.plot(kind='pie', figsize=[10,10], title="Titulo", 
         fontsize=30, shadow=True, 
         explode=(0, 0.1, 0.2, 0.3), autopct='%1.1f%%', 
         startangle=90)

# %% [markdown]
# ## Graficas de barras
# barplot(): https://seaborn.pydata.org/generated/seaborn.barplot.html \
# countplot(): https://seaborn.pydata.org/generated/seaborn.countplot.html

# %%
sns.barplot(x=tip['day'].value_counts().index, 
            y=tip['day'].value_counts())

# %%
sns.countplot(data=tip, x='day', 
              order=['Thur', 'Fri', 'Sat', 'Sun'])

# %%
sns.barplot(x="day", y="total_bill", data=tip)

# %%
sns.barplot(x="day", y="total_bill", 
            hue="sex", data=tip)

# %%
sns.barplot(x="day", y="tip", data=tip, 
            estimator=np.std, capsize=.2)

# %%
sns.countplot(x="class", hue="who", 
              data=titanic)

# %%
sns.countplot(x="who", data=titanic,
              facecolor=(0, 0, 0, 0),
              linewidth=5,
              edgecolor=sns.color_palette("dark", 3))

# %%
sns.catplot(x="class", hue="who", col="survived",
            data=titanic, kind="count",
            height=4, aspect=.7);

# %% [markdown]
# #### Paletas de color
# https://chrisalbon.com/python/data_visualization/seaborn_color_palettes/

# %%
#Secuencial
sns.palplot(sns.color_palette("Paired", 10))

# %%
#Continua
sns.palplot(sns.color_palette("YlGnBu", 10))

# %%
#Divergente
sns.palplot(sns.color_palette("RdYlGn", 10))

# %%
f = plt.figure(figsize=(6, 6))
gs = f.add_gridspec(2, 2)

ax = f.add_subplot(gs[0, 0])
sns.countplot(x="class", hue="who", 
              data=titanic)

with sns.color_palette("YlGnBu"):
    ax = f.add_subplot(gs[0, 1])
    sns.countplot(x="class", hue="who", 
                  data=titanic)

with sns.color_palette("RdYlGn"):
    ax = f.add_subplot(gs[1, 0])
    sns.countplot(x="class", hue="who", 
                  data=titanic)

with sns.color_palette("Paired"):
    ax = f.add_subplot(gs[1, 1])
    sns.countplot(x="class", hue="who", 
                  data=titanic)
    

f.tight_layout()

# %%
#Dejar una paleta de colores default
sns.set_palette("husl")
sns.barplot(x="day", y="total_bill", data=tip)

# %%
#Crear una paleta secuencial
colors = ["windows blue", "amber", "greyish", "dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %%
sns.palplot(sns.dark_palette("purple"))
sns.palplot(sns.light_palette("navy", reverse=True))

# %%
div=sns.choose_diverging_palette()
# Out:
# interactive(children=(IntSlider(value=220, description='h_neg', max=359), IntSlider(value=10, description='h_p…

# %%
dark=sns.choose_dark_palette()
# Out:
# interactive(children=(IntSlider(value=179, description='h', max=359), IntSlider(value=49, description='s', max…

# %%
light=sns.choose_light_palette()
# Out:
# interactive(children=(IntSlider(value=179, description='h', max=359), IntSlider(value=49, description='s', max…

# %%
light.reverse()
sns.palplot(light)

# %%
f = plt.figure(figsize=(6, 6))
gs = f.add_gridspec(2, 2)

ax = f.add_subplot(gs[0, 0])
sns.countplot(x="class", hue="who", 
              data=titanic)

with sns.color_palette(div):
    ax = f.add_subplot(gs[0, 1])
    sns.countplot(x="class", hue="who", 
                  data=titanic)

with sns.color_palette(dark):
    ax = f.add_subplot(gs[1, 0])
    sns.countplot(x="class", hue="who", 
                  data=titanic)

with sns.color_palette(light):
    ax = f.add_subplot(gs[1, 1])
    sns.countplot(x="class", hue="who", 
                  data=titanic)
    

f.tight_layout()

# %% [markdown]
# ### Categoricas

# %%
sns.boxplot(x=tip["percent"])

# %%
sns.boxplot(x="day", y="percent", data=tip)

# %%
ax = sns.boxplot(x="day", y="percent", 
                 hue="smoker",data=tip, 
                 palette="Paired")

# %%
sns.swarmplot(data=iris)

# %%
sns.boxplot(data=iris)
sns.swarmplot(data=iris, color="k", 
              alpha=0.5, size=3)

# %%
sns.boxenplot(data=iris)

# %%
sns.violinplot(x=tip["percent"])

# %%
ax = sns.violinplot(x="day", y="percent", 
                    hue="sex", data=tip, 
                    palette=['royalblue','lightpink'])

# %%
sns.violinplot(x="day", y="percent", 
               hue="sex", data=tip, split=True, 
               palette=['royalblue','lightpink'])

# %%
sns.violinplot(data=iris, inner="quartile")

# %%
sns.violinplot(data=iris, inner="stick")

# %%
sns.violinplot(data=iris, inner="stick", bw=.07)

# %%
sns.catplot(kind="violin", x="day", 
            y="percent", data=tip, 
            col="smoker", row="sex", 
            palette="viridis")

# %% [markdown]
# ### Puntos
# https://seaborn.pydata.org/generated/seaborn.pointplot.html

# %%
sns.pointplot(x="time", y="total_bill", 
              data=tip)

# %%
sns.pointplot(x="time", y="total_bill", 
              hue="smoker", data=tip, 
              dodge=True)

# %%
sns.pointplot(x="time", y="total_bill", 
              hue="smoker", data=tip, 
              linestyles=["-", "--"])

# %%
sns.scatterplot(data=iris, x="sepal_length", 
                y="sepal_width")

# %%
sns.scatterplot(data=iris, x="sepal_length", 
                y="sepal_width", hue="species")

# %%
ax = sns.scatterplot(x="total_bill", y="percent", 
                     size="size", hue="size",
                     data=tip)

# %% [markdown]
# ### Regresiones
# https://seaborn.pydata.org/generated/seaborn.lmplot.html

# %%
g=sns.lmplot(x="total_bill",                    
           y="percent",                    
           data=tip)
g = (g.set_axis_labels("Cuenta total", "Porcentage").set(xlim=(0,60),ylim=(0,1)))
plt.title("Propina pagada por costo de cuenta")
plt.show(g)

# %%
g=sns.lmplot(x="total_bill",                    
           y="percent",                    
           data=tip,
            aspect=4, 
            order=2)
g = (g.set_axis_labels("Porcentage","Cuenta total").set(xlim=(0,60),ylim=(0,1)))
plt.title("Propina pagada por costo de cuenta")
plt.show(g)

# %%
sns.jointplot(x="total_bill",                    
              y="percent",                    
              data=tip, 
              kind="reg")

# %%
sns.lmplot(x="sepal_width", y="petal_width", 
           data=iris, aspect=3)

# %% [markdown]
# Se pueden cambiar los marcadores, a cuales en https://matplotlib.org/3.1.3/api/markers_api.html

# %%
sns.lmplot(x="sepal_width", y="petal_width", hue="species", 
           data=iris, aspect=4, markers=['x','s','v'], 
           palette="gist_rainbow")

# %%
sns.lmplot(x="total_bill", y="percent",
           row="smoker", col='sex', data=tip);

# %% [markdown]
# ### Analisis rapido

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %%
g = sns.PairGrid(iris, hue="species")
g = g.map_upper(plt.scatter)
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_lower(plt.scatter)
g = g.add_legend()

# %%
g = sns.PairGrid(iris)
g = g.map_upper(sns.scatterplot)
g = g.map_lower(sns.kdeplot)
g = g.map_diag(sns.kdeplot, lw=2)
